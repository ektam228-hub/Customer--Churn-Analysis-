# %% [markdown]
# <a href="https://colab.research.google.com/github/ektam228-hub/Customer--Churn-Analysis-/blob/main/customer_churn_prediction_using_Machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print("All LIBAREIES LOADED SUSCCESFULLY")
# Out:
# All LIBAREIES LOADED SUSCCESFULLY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customerID       10 non-null     object
#  1   gender           10 non-null     object
#  2   SeniorCitizen    10 non-null     int64
#  3   Partner          10 non-null     object
#  4   Dependents       10 non-null     object
#  5   tenure           10 non-null     int64
#  6   PhoneService     10 non-null     object
#  7   InternetService  10 non-null     object
#  8   Contract         10 non-null     object
#  9   MonthlyCharges   10 non-null     float64
#  10  TotalCharges     10 non-null     float64
#  11  Churn            10 non-null     object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 1.1+ KB

# %%
df.isnull().sum()
# Out:
# customerID         0
# gender             0
# SeniorCitizen      0
# Partner            0
# Dependents         0
# tenure             0
# PhoneService       0
# InternetService    0
# Contract           0
# MonthlyCharges     0
# TotalCharges       0
# Churn              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# customerID         10
# gender              2
# SeniorCitizen       1
# Partner             2
# Dependents          2
# tenure              9
# PhoneService        2
# InternetService     2
# Contract            3
# MonthlyCharges     10
# TotalCharges       10
# Churn               2
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen     tenure  MonthlyCharges  TotalCharges
# count           10.0  10.000000       10.000000     10.000000
# mean             0.0  21.400000       63.310000   1362.570000
# std              0.0  20.780333       27.142062   1266.531833
# min              0.0   1.000000       29.750000     29.850000
# 25%              0.0   3.500000       45.187500    189.212500
# 50%              0.0  16.000000       56.550000   1330.625000
# 75%              0.0  32.500000       84.500000   1934.425000
# max              0.0  62.000000      104.800000   3487.950000

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     6
# Yes    4
# Name: count, dtype: int64

# %%
df["Churn"]= df["Churn"].map({"yes":1,"NO":0})

# %%
df["Churn"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df["Churn"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  \
# 0              0       1           29.85         29.85    NaN
# 1              0      34           56.95       1889.50    NaN
# 2              0       2           53.85        108.15    NaN
# 3              0      45           42.30       1840.75    NaN
# 4              0       2           70.70        151.65    NaN
#
#    customerID_3668-QPYBK  customerID_5575-GNVDE  customerID_6388-TABGU  \
# 0                  False                  False                  False
# 1                  False                   True                  False
# 2                   True                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    customerID_6713-OKOMC  customerID_7590-VHVEG  ...  customerID_7892-POOKP  \
# 0                  False                   True  ...                  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   SeniorCitizen                10 non-null     int64
#  1   tenure                       10 non-null     int64
#  2   MonthlyCharges               10 non-null     float64
#  3   TotalCharges                 10 non-null     float64
#  4   Churn                        0 non-null      float64
#  5   customerID_3668-QPYBK        10 non-null     bool
#  6   customerID_5575-GNVDE        10 non-null     bool
#  7   customerID_6388-TABGU        10 non-null     bool
#  8   customerID_6713-OKOMC        10 non-null     bool
#  9   customerID_7590-VHVEG        10 non-null     bool
#  10  customerID_7795-CFOCW        10 non-null     bool
#  11  customerID_7892-POOKP        10 non-null     bool
#  12  customerID_9237-HQITU        10 non-null     bool
# ...

# %%
df.isnull().sum()
# Out:
# SeniorCitizen                   0
# tenure                          0
# MonthlyCharges                  0
# TotalCharges                    0
# Churn                          10
# customerID_3668-QPYBK           0
# customerID_5575-GNVDE           0
# customerID_6388-TABGU           0
# customerID_6713-OKOMC           0
# customerID_7590-VHVEG           0
# customerID_7795-CFOCW           0
# customerID_7892-POOKP           0
# customerID_9237-HQITU           0
# customerID_9305-CDSKC           0
# gender_Male                     0
# Partner_Yes                     0
# Dependents_Yes                  0
# PhoneService_Yes                0
# InternetService_Fiber optic     0
# Contract_One year               0
# Contract_Two year               0
# dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df[df['Churn'].isnull()]
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  \
# 0              0       1           29.85         29.85    NaN
# 1              0      34           56.95       1889.50    NaN
# 2              0       2           53.85        108.15    NaN
# 3              0      45           42.30       1840.75    NaN
# 4              0       2           70.70        151.65    NaN
# 5              0       8           99.65        820.50    NaN
# 6              0      22           89.10       1949.40    NaN
# 7              0      10           29.75        301.90    NaN
# 8              0      28          104.80       3046.05    NaN
# 9              0      62           56.15       3487.95    NaN
#
#    customerID_3668-QPYBK  customerID_5575-GNVDE  customerID_6388-TABGU  \
# 0                  False                  False                  False
# 1                  False                   True                  False
# ...

# %%
df['Churn'].value_counts(dropna=False)
# Out:
# Churn
# NaN    10
# Name: count, dtype: int64

# %%
df['Churn'].isnull().sum()
# Out:
# np.int64(10)

# %%
df=df.dropna(subset=['Churn'])

# %%
df['Churn'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'InternetService', 'Contract',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Churn'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.shape
# Out:
# (0, 21)

# %%
import pandas as pd
df=pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn (1).csv')
df.shape
# Out:
# (10, 12)

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (10, 13)
# ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'InternetService', 'Contract', 'MonthlyCharges', 'TotalCharges', 'Churn', 'Monthlycharges']

# %%
df.shape
# Out:
# (10, 13)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'InternetService', 'Contract',
#        'MonthlyCharges', 'TotalCharges', 'Churn', 'Monthlycharges'],
#       dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'InternetService', 'Contract', 'MonthlyCharges', 'TotalCharges', 'Churn', 'Monthlycharges']

# %%
print([col for col in df.columns if 'churn'in col])
# Out:
# []

# %%
print(df.columns.tolist())
# Out:
# ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'InternetService', 'Contract', 'MonthlyCharges', 'TotalCharges', 'Churn', 'Monthlycharges']

# %%
df['Churn'].value_counts(dropna=False)
# Out:
# Churn
# No     6
# Yes    4
# Name: count, dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'InternetService', 'Contract', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %%
print([repr(col)for col in df.columns])
# Out:
# ["'customerID'", "'gender'", "'SeniorCitizen'", "'Partner'", "'Dependents'", "'tenure'", "'PhoneService'", "'InternetService'", "'Contract'", "'MonthlyCharges'", "'TotalCharges'", "'Churn'"]

# %%
import pandas as pd
df=pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn (1).csv')
print(df.shape)
# Out:
# (10, 12)

# %%
print(df.columns.tolist())
# Out:
# ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'InternetService', 'Contract', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %%
for col in df. columns:
  print(repr(col))
# Out:
# 'customerID'
# 'gender'
# 'SeniorCitizen'
# 'Partner'
# 'Dependents'
# 'tenure'
# 'PhoneService'
# 'InternetService'
# 'Contract'
# 'MonthlyCharges'
# 'TotalCharges'
# 'Churn'
# 'Monthlycharges'

# %%
[col for col in df.columns if 'Monthly'in str(col)]
# Out:
# ['MonthlyCharges']

# %%
monthly_col=df.columns[9]
print(monthly_col)
# Out:
# MonthlyCharges

# %%
import matplotlib.pyplot as plt
plt.hist(df['MonthlyCharges'],bins=5)
plt.title('MonthlyChargesDistribution')
plt.xlabel('MonthlyCharges')
plt.ylabel('number of Customrs')
plt.show()

# %%
print(df.groupby('Churn')
['MonthlyCharges'].mean())
# Out:
# Churn
# No     50.683333
# Yes    82.250000
# Name: MonthlyCharges, dtype: float64

# %%
df['Monthlycharges']=pd.to_numeric(df['MonthlyCharges'],errors='coerce')

# %%
import matplotlib.pyplot as plt
plt.bar(['No','yes'],[50.683333,82.25])
# Out:
# <BarContainer object of 2 artists>

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     6
# Yes    4
# Name: count, dtype: int64

# %%
df['Churn'].value_counts(normalize=True)*100
# Out:
# Churn
# No     60.0
# Yes    40.0
# Name: proportion, dtype: float64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'InternetService', 'Contract',
#        'MonthlyCharges', 'TotalCharges', 'Churn', 'Monthlycharges'],
#       dtype='object')

# %%
! pip insptall numpy
# Out:
# ERROR: unknown command "insptall" - maybe you meant "install"

# %%
pd.columns =df.columns.str.strip()

# %%
pd.crosstab(df['Contract'],df['Churn'])
# Out:
# Churn           No  Yes
# Contract
# Month-to-month   2    4
# One year         3    0
# Two year         1    0
